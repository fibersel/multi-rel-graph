# %%
from neo4j import GraphDatabase
from dataclasses import dataclass
from collections import defaultdict
from typing import Any

# %%
@dataclass
class Attr:
    name: str
    data_type: str
    nullable: bool
        
@dataclass
class FK:
    source_attr_name: str
    target_table: str
    target_attr_name: str

# %%
class Node:
    def __init__(self, label, attr, vals):
        self.vals = vals
        self.label = label
        self.attr = attr
        
class Edge:
    def __init__(self, label, source, target, attr=[], vals=[]):
        self.label = label
        self.source = source
        self.target = target
        self.attr = attr
        self.vals = vals

# %%
@dataclass(frozen=True)
class Node:
    label: str
    attr: list[str]
    vals: list[Any]
        
@dataclass(frozen=True)
class Edge:
    label: str
    attr: list[str]
    vals: list[Any]
    source: Node
    target: Node

# %%
class NodeClass:
    def __init__(self, label, attr, pk, nodes):
        self.label = label
        self.pk = pk
        self.nodes = nodes
        self.attr = attr


class EdgeClass:
    def __init__(self, label, source, target, attr, edges):
        self.label = label
        self.source = source
        self.target = target
        self.attr = attr
        self.edges = edges

# %%
class GraphSchema:
    
    def __init__(self, nodes, edges):
        self.nodes = nodes
        self.edges = edges

# %%
class Table:
    def __init__(self, name):
        self.name = name
        self.attr = []
        self.fk = []
        self.pk = set()
        self.is_referenced = False
        self.tuples = []
        
    def add_attr(self, attr):
        self.attr.append(attr)
        
    def add_fk(self, source_attribute, target_table_name, target_attribute):
        self.fk.append(FK(source_attribute, target_table_name, target_attribute))
        
    def add_pk(self, attr):
        self.pk.add(attr)
        
    def is_m2m(self):
        if self.is_referenced:
            return False
        
        refcnt = 0
        c = set()
        for fk in self.fk:
            if fk.source_attr_name not in self.pk:
                return False
            if fk.target_table not in c:
                c.add(target_table)
                refcnt += 1
        if refcnt != 2:
            return False
        
        return True
    
    def extract_tables(self):
        if not self.is_m2m():
            raise RuntimeError("exctracting edges is possible only for m2m tables")
            
        targets = []
        for fk in self.fk:
            target_table = fk.target_table
            targets.append(target_table)
            
        return sorted(targets)

# %%
TABLE_PRIMARY_KEYS = {
    "suppliers": {'supplier_id'},
    "customer_demographics": {'customer_type_id'},
    "territories": {'territory_id'},
    "shippers": {'shipper_id'},
    "orders": {'order_id'},
    "customer_customer_demo": {'customer_type_id', 'customer_id'},
    "order_details": {'product_id', 'order_id'},
    "employees": {'employee_id'},
    "categories": {'category_id'},
    "employee_territories": {'employee_id', 'territory_id'},
    "customers": {'customer_id'},
    "products": {'product_id'},
    "region": {'region_id'},
    "us_states": {'state_id'}
}

# %%
driver = GraphDatabase.driver("neo4j://localhost:7687", auth=("neo4j", "password"))

# %%
with driver.session() as session:
    result = session.run("match (n) return n")

# %%
uri = "neo4j://localhost:7687"
user = "neo4j"
password = "password"

# %%
def nodeMapper(nodeRec):
    label = list(nodeRec.labels)[0]
    attrs = tuple(k for k in nodeRec)
    vals = tuple(nodeRec[k] for k in nodeRec)
    return Node(label, attrs, vals)

# %%
def edgeMapper(edgeRec, src, dst):
    label = edgeRec.type
    attrs = tuple(k for k in edgeRec)
    vals = tuple(edgeRec[k] for k in edgeRec)
    return Edge(label, attrs, vals, src, dst)

# %%
driver = GraphDatabase.driver(uri, auth=(user, password))
session = driver.session()
result = session.run("match (a)-[b]->(c) return a,b,c")
triplets = []

for s, e, t in result:
    s = nodeMapper(s)
    t = nodeMapper(t)
    e = edgeMapper(e, s, t)
    triplets.append((s, e, t))
    
results2 = session.run("match (a) return a") # merge nodes without edges

# %%
tuples = defaultdict(set)

for n1, _, n2 in triplets:
    l = n1.label
    tuples[l].add(n1)
    l = n2.label
    tuples[l].add(n2)

for n1 in results2:
    for n2 in n1:
        s = nodeMapper(n2)
        l = s.label
        tuples[l].add(s)
    
for k in tuples:
    tuples[k] = list(tuples[k])

# %%
session.close()

# %%
for k in tuples:
    print(k, len(tuples[k]))
# Out:
# territories 53
# employees 9
# region 4
# orders 830
# shippers 6
# customers 91
# products 77
# suppliers 29
# categories 8
# us_states 51

# %%
ncs = []
for k, v in tuples.items():
    label = k
    a2t = {}
    for n in v:
        attrs = n.attr
        vals = n.vals
        for i in range(len(attrs)):
            attr = attrs[i]
            tp = type(vals[i])    
            a2t[attr] = tp
    attrs = [Attr(k, a2t[k], False) for k in a2t]
    nc = NodeClass(label, attrs, set(), v)
    ncs.append(nc)

# %%
edgesSets = defaultdict(set)

for s, e, t in triplets:
    label = e.label
    edgesSets[label].add(e)

# %%
ecs = []

for k, v in edgesSets.items():
    label = k
    a2t = {}
    for e in v:
        attrs = e.attr
        vals = e.vals
        source = e.source.label
        target = e.target.label
        for i in range(len(attrs)):
            attr = attrs[i]
            tp = type(vals[i])
            a2t[attr] = tp
            
    attrs = [Attr(k, a2t[k], False) for k in a2t]
    ec = EdgeClass(label, source, target, attrs, v)
    ecs.append(ec)

# %%
for ec in ecs:
    print(ec.label, ec.attr)
# Out:
# employee_territories [Attr(name='territory_id', data_type=<class 'str'>, nullable=False), Attr(name='employee_id', data_type=<class 'int'>, nullable=False)]
# region_id []
# ship_via []
# employee_id []
# customer_id []
# reports_to []
# order_details [Attr(name='discount', data_type=<class 'float'>, nullable=False), Attr(name='quantity', data_type=<class 'int'>, nullable=False), Attr(name='unit_price', data_type=<class 'float'>, nullable=False), Attr(name='order_id', data_type=<class 'int'>, nullable=False), Attr(name='product_id', data_type=<class 'int'>, nullable=False)]
# supplier_id []
# category_id []

# %%
# process primary keys

# %%
for nc in ncs:
    keys = TABLE_PRIMARY_KEYS[nc.label]
    nc.pk = keys

# %%
def is_m2m(edge_class):
    sources = set()
    targets = set()
    src_many = False
    tgt_many = False
    has_attr = False
    
    for e in edge_class:
        if e.vals:
            has_attr = True
        
        if e.source in sources:
            tgt_many = True
        sources.add(e.source)
        
        if e.target in targets:
            src_many = True
        targets.add(e.target)
        
        
    return src_many, tgt_many, has_attr

# %%
for ec in ecs:
    src_many, tgt_many, has_attr = is_m2m(ec.edges)
    if has_attr or (src_many and tgt_many):
        print(generate_migration(ec))
        print("\n\n")
# Out:
# CREATE TABLE employee_territories  (
# 	territory_id  text,
# 	employee_id  smallint
# );
#
#
#
# CREATE TABLE order_details  (
# 	discount  real,
# 	quantity  smallint,
# 	unit_price  real,
# 	order_id  smallint,
# 	product_id  smallint
# );

# %%
def generate_deletion(nc):
    query = f"""DROP TABLE IF EXISTS {nc.label};"""
    
    return query

# %%
def generate_migration(nc):
    tablename = nc.label
    query = f"""CREATE TABLE {tablename} """ + " (\n"
    parts = []
    for attr in nc.attr:
        part = ""
        if attr.data_type == float:
            tp = ' real'
        elif attr.data_type == int:
            tp = ' smallint'
        elif attr.data_type == str:
            tp = ' text'
        part += f"\t{attr.name} {tp}"
        if attr.nullable:
            part += " NOT NULL"
        parts.append(part)
        # query += ",\n"
    query += ",\n".join(parts)
    return query + "\n);"

# %%
def generate_pk_constraint(nc):
    tablename = nc.label
    pk = list(nc.pk)[0]
    q_tpl = f"ALTER TABLE ONLY {tablename} ADD CONSTRAINT pk_{tablename} PRIMARY KEY ({pk});"
    return q_tpl

# %%
def generate_inserts_for_nodeClass(nc):
    
    tpl = "INSERT INTO {} ({}) VALUES ({});"
    res = []
    for node in nc.nodes:
        t = []

        for val in node.vals:
            if isinstance(val, str):
                val = val.replace("'", "''")
                val = "\'" + val + "\'"
            else:
                val = str(val)
            t.append(val)
            
        res.append(tpl.format(node.label, ",".join(node.attr), ",".join(t)))
    return res
        
    return [tpl.format(node.label, ",".join(node.attr), node.vals) for node in nc.nodes]

# %%
def generate_inserts_for_edgeClass(ec):
    
    tpl = "INSERT INTO {} ({}) VALUES {};"
        
    return [tpl.format(edge.label, ",".join(edge.attr), edge.vals) for edge in ec.edges]

# %%
for nc in ncs:
    print(*generate_inserts_for_nodeClass(nc), sep="\n")
# Out:
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Cary','27511');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Hoffman Estates','60179');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Seattle','98104');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Morristown','07960');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Santa Clara','95054');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Philadelphia','19428');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (4,'Bentonville','72716');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Redmond','98052');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Boston','02116');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Bedford','01730');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Campbell','95008');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Rockville','20852');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'New York','10038');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Mellvile','11747');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (4,'Columbia','29202');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Fairport','14450');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Edison','08837');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Minneapolis','55439');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Providence','02903');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'New York','10019');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Racine','53404');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (4,'Dallas','75234');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'San Francisco','94105');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Phoenix','85014');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Bellevue','98004');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Braintree','02184');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Cambridge','02139');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Findlay','45839');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Roseville','55113');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Santa Monica','90405');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (4,'Tampa','33607');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Louisville','40222');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Southfield','48075');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Colorado Springs','80909');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (4,'Atlanta','30346');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Chicago','60601');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Wilton','06897');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Menlo Park','94025');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Portsmouth','03801');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (4,'Savannah','31406');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Greensboro','27403');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Westboro','01581');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Hollis','03049');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Bloomfield Hills','48304');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Beachwood','44122');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (4,'Austin','78759');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Neward','19713');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (4,'Orlando','32859');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Denver','80202');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Santa Cruz','95060');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (1,'Georgetow','01833');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (3,'Troy','48084');
# INSERT INTO territories (region_id,territory_description,territory_id) VALUES (2,'Scottsdale','85251');
# INSERT INTO employees (home_phone,country,extension,notes,address,title_of_courtesy,city,birth_date,last_name,photo,hire_date,title,photo_path,reports_to,employee_id,postal_code,region,first_name) VALUES ('(206) 555-9857','USA','5467','Education includes a BA in psychology from Colorado State University in 1970.  She also completed The Art of the Cold Call.  Nancy is a member of Toastmasters International.','507 - 20th Ave. E.
# Apt. 2A','Ms.','Seattle','1948-12-08','Davolio','<memory at 0x126336f40>','1992-05-01','Sales Representative','http://accweb/emmployees/davolio.bmp',2,1,'98122','WA','Nancy');
# INSERT INTO employees (home_phone,country,extension,notes,address,title_of_courtesy,city,birth_date,photo,last_name,hire_date,title,photo_path,reports_to,employee_id,region,postal_code,first_name) VALUES ('(206) 555-3412','USA','3355','Janet has a BS degree in chemistry from Boston College (1984).  She has also completed a certificate program in food retailing management.  Janet was hired as a sales associate in 1991 and promoted to sales representative in February 1992.','722 Moss Bay Blvd.','Ms.','Kirkland','1963-08-30','<memory at 0x1265a0280>','Leverling','1992-04-01','Sales Representative','http://accweb/emmployees/leverling.bmp',2,3,'WA','98033','Janet');
# INSERT INTO employees (home_phone,country,extension,notes,address,title_of_courtesy,city,birth_date,photo,last_name,hire_date,title,photo_path,reports_to,employee_id,region,postal_code,first_name) VALUES ('(206) 555-8122','USA','5176','Margaret holds a BA in English literature from Concordia College (1958) and an MA from the American Institute of Culinary Arts (1966).  She was assigned to the London office temporarily from July through November 1992.','4110 Old Redmond Rd.','Mrs.','Redmond','1937-09-19','<memory at 0x1265a0400>','Peacock','1993-05-03','Sales Representative','http://accweb/emmployees/peacock.bmp',2,4,'WA','98052','Margaret');
# INSERT INTO employees (home_phone,country,extension,notes,address,title_of_courtesy,city,birth_date,photo,last_name,hire_date,title,photo_path,employee_id,region,postal_code,first_name) VALUES ('(206) 555-9482','USA','3457','Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.','908 W. Capital Way','Dr.','Tacoma','1952-02-19','<memory at 0x1265a0100>','Fuller','1992-08-14','Vice President, Sales','http://accweb/emmployees/fuller.bmp',2,'WA','98401','Andrew');
# INSERT INTO employees (home_phone,country,extension,notes,address,title_of_courtesy,city,birth_date,last_name,photo,hire_date,title,photo_path,reports_to,employee_id,postal_code,first_name) VALUES ('(71) 555-7773','UK','428','Michael is a graduate of Sussex University (MA, economics, 1983) and the University of California at Los Angeles (MBA, marketing, 1986).  He has also taken the courses Multi-Cultural Selling and Time Management for the Sales Professional.  He is fluent in Japanese and can read and write French, Portuguese, and Spanish.','Coventry House
# Miner Rd.','Mr.','London','1963-07-02','Suyama','<memory at 0x1265a0700>','1993-10-17','Sales Representative','http://accweb/emmployees/davolio.bmp',5,6,'EC2 7JR','Michael');
# INSERT INTO employees (home_phone,country,extension,notes,address,title_of_courtesy,city,birth_date,photo,last_name,hire_date,title,photo_path,reports_to,employee_id,postal_code,first_name) VALUES ('(71) 555-4444','UK','452','Anne has a BA degree in English from St. Lawrence College.  She is fluent in French and German.','7 Houndstooth Rd.','Ms.','London','1966-01-27','<memory at 0x1265a0b80>','Dodsworth','1994-11-15','Sales Representative','http://accweb/emmployees/davolio.bmp',5,9,'WG2 7LT','Anne');
# INSERT INTO employees (home_phone,country,extension,notes,address,title_of_courtesy,city,birth_date,photo,last_name,hire_date,title,photo_path,reports_to,employee_id,region,postal_code,first_name) VALUES ('(206) 555-1189','USA','2344','Laura received a BA in psychology from the University of Washington.  She has also completed a course in business French.  She reads and writes French.','4726 - 11th Ave. N.E.','Ms.','Seattle','1958-01-09','<memory at 0x1265a0a00>','Callahan','1994-03-05','Inside Sales Coordinator','http://accweb/emmployees/davolio.bmp',2,8,'WA','98105','Laura');
# INSERT INTO employees (home_phone,country,extension,address,notes,title_of_courtesy,city,birth_date,photo,last_name,hire_date,title,photo_path,reports_to,employee_id,postal_code,first_name) VALUES ('(71) 555-4848','UK','3453','14 Garrett Hill','Steven Buchanan graduated from St. Andrews University, Scotland, with a BSC degree in 1976.  Upon joining the company as a sales representative in 1992, he spent 6 months in an orientation program at the Seattle office and then returned to his permanent post in London.  He was promoted to sales manager in March 1993.  Mr. Buchanan has completed the courses Successful Telemarketing and International Sales Management.  He is fluent in French.','Mr.','London','1955-03-04','<memory at 0x1265a0580>','Buchanan','1993-10-17','Sales Manager','http://accweb/emmployees/buchanan.bmp',2,5,'SW1 8JR','Steven');
# INSERT INTO employees (home_phone,country,extension,notes,address,title_of_courtesy,city,birth_date,photo,last_name,hire_date,title,photo_path,employee_id,reports_to,postal_code,first_name) VALUES ('(71) 555-5598','UK','465','Robert King served in the Peace Corps and traveled extensively before completing his degree in English at the University of Michigan in 1992, the year he joined the company.  After completing a course entitled Selling in Europe, he was transferred to the London office in March 1993.','Edgeham Hollow
# Winchester Way','Mr.','London','1960-05-29','<memory at 0x1265a0880>','King','1994-01-02','Sales Representative','http://accweb/emmployees/davolio.bmp',7,5,'RG1 9SP','Robert');
# INSERT INTO region (region_id,region_description) VALUES (3,'Northern');
# INSERT INTO region (region_id,region_description) VALUES (4,'Southern');
# INSERT INTO region (region_id,region_description) VALUES (2,'Western');
# INSERT INTO region (region_id,region_description) VALUES (1,'Eastern');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Luleå','S-958 22','1996-09-09',92.69,'1996-08-12','1996-08-16',8,2,'Berguvsvägen  8','BERGS','Berglunds snabbköp',10278,'Sweden');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('28001','Madrid','1996-10-14',7.56,'1996-09-16','1996-09-23',1,3,'ROMEY','Gran Vía, 1','Romero y tomillo',10306,'Spain');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('83720','Boise','1997-03-10',86.53,'ID','1997-02-10','1997-02-28',4,2,'SAVEA','187 Suffolk Ln.',10440,'Save-a-lot Markets','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01307','Cunewalde','1998-01-01',42.74,'1997-12-04','1997-12-09',3,3,'QUICK','Taucherstraße 10',10765,'QUICK-Stop','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('97827','Elgin','1997-08-13',45.13,'OR','1997-07-16','1997-07-21',4,1,'HUNGC','City Center Plaza 516 Main St.','Hungry Coyote Import Store',10600,'USA');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('Sao Paulo','05634-030','1997-05-02',46.77,'SP','1997-04-04','1997-04-07',7,2,'TRADH','Av. Inês de Castro, 414','Tradiçao Hipermercados',10496,'Brazil');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('San Cristóbal','5022','1998-05-26',120.92,'Táchira','1998-04-28','1998-05-05',7,2,'HILAA','Carrera 22 con Ave. Carlos Soublette #8-35','HILARION-Abastos',11055,'Venezuela');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Rio de Janeiro','05454-876','1998-05-12',6.27,'RJ','1998-04-14','1998-05-04',9,2,'Rua do Paço, 67','HANAR','Hanari Carnes',11022,'Brazil');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('1204','Genève','1997-10-10',232.42,'1997-09-12','1997-09-22',7,2,'RICSU','Starenweg 5','Richter Supermarkt',10666,'Switzerland');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('05033','México D.F.','1997-05-09',218.15,'1997-04-25','1997-05-05',4,2,'TORTU','Avda. Azteca 123',10518,'Tortuga Restaurante','Mexico');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Charleroi','B-6000','1998-04-17',15.55,'1998-03-06','1998-03-18',4,3,'Boulevard Tirou, 255','SUPRD','Suprêmes délices',10930,'Belgium');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('44000','Nantes','1998-04-21',121.82,'1998-03-24','1998-04-02',2,2,'FRANR','54, rue Royale',10971,'France restauration','France');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('1010','Buenos Aires','1998-05-11',3.17,'1998-04-13',6,3,'RANCH','Av. del Libertador 900','Rancho grande',11019,'Argentina');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('42100','Reggio Emilia','1998-01-30',59.78,'1998-01-02','1998-01-12',5,1,'REGGC','Strada Provinciale 124',10812,'Reggiani Caseifici','Italy');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('London','WX3 6FW','1998-05-12',278.96,'1998-04-28','1998-05-01',8,2,'EASTC','35 King George',11056,'Eastern Connection','UK');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Sao Paulo','05442-030','1997-02-11',21.48,'SP','1997-01-14','1997-01-17',2,3,'Rua Orós, 92','FAMIA','Familia Arquibaldo',10414,'Brazil');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Cowes','PO31 7PJ','1996-10-24',41.76,'Isle of Wight','1996-09-26','1996-10-03',4,2,'Garden House Crowther Way','ISLAT','Island Trading',10315,'UK');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('Rio de Janeiro','02389-673','1996-09-24',6.4,'RJ','1996-08-27','1996-09-04',6,2,'QUEDE','Rua da Panificadora, 12','Que Delícia',10291,'Brazil');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('97403','Eugene','1997-08-28',116.53,'OR','1997-07-31','1997-08-05',1,2,'GREAL','2732 Baker Blvd.',10616,'Great Lakes Food Market','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('97827','Elgin','1997-02-12',0.2,'OR','1997-01-15','1997-01-24',3,1,'HUNGC','City Center Plaza 516 Main St.','Hungry Coyote Import Store',10415,'USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('14776','Brandenburg','1998-03-18',77.78,'1998-02-18','1998-02-20',9,2,'KOENE','Maubelstr. 90',10893,'Königlich Essen','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('97827','Elgin','1997-01-03',20.12,'OR','1996-12-06','1996-12-09',3,2,'HUNGC','City Center Plaza 516 Main St.','Hungry Coyote Import Store',10375,'USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('12209','Berlin','1998-04-27',40.42,'1998-03-16','1998-03-24',1,1,'ALFKI','Obere Str. 57',10952,'Alfred''s Futterkiste','Germany');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('Sao Paulo','05487-020','1997-10-03',105.81,'SP','1997-09-05','1997-09-10',7,2,'QUEEN','Alameda dos Canàrios, 891','Queen Cozinha',10659,'Brazil');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('London','EC2 5NT','1998-04-08',2.17,'1998-03-11','1998-03-19',4,2,'Fauntleroy Circus','BSBEV','B''s Beverages',10943,'UK');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('I. de Margarita','4980','1997-09-17',158.44,'Nueva Esparta','1997-08-20','1997-09-01',3,1,'Ave. 5 de Mayo Porlamar','LINOD','LINO-Delicateses',10638,'Venezuela');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('70563','Stuttgart','1997-10-13',47.22,'1997-09-15','1997-09-23',1,2,'WANDK','Adenauerallee 900',10668,'Die Wandernde Kuh','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('3508','Barquisimeto','1997-12-30',42.13,'Lara','1997-12-16','1997-12-25',2,1,'LILAS','Carrera 52 con Ave. Bolívar #65-98 Llano Largo','LILA-Supermercado',10780,'Venezuela');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01307','Cunewalde','1998-01-19',42.7,'1997-12-22','1998-01-19',1,2,'QUICK','Taucherstraße 10',10788,'QUICK-Stop','Germany');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Tsawassen','T2F 8M4','1998-04-10',74.44,'BC','1998-03-13','1998-03-17',2,3,'23 Tsawassen Blvd.','BOTTM','Bottom-Dollar Markets',10949,'Canada');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('8010','Graz','1998-04-23',353.07,'1998-03-26','1998-03-31',8,2,'Kirchgasse 6','ERNSH','Ernst Handel',10979,'Austria');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('1756','Lisboa','1998-05-06',202.24,'1998-04-08','1998-04-13',8,2,'PRINI','Estrada da saúde n. 58','Princesa Isabel Vinhos',11007,'Portugal');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('41101','Sevilla','1997-09-09',85.46,'1997-08-12','1997-08-20',4,3,'GODOS','C/ Romero, 33',10629,'Godos Cocina Típica','Spain');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('97403','Eugene','1998-05-05',25.19,'OR','1998-04-07','1998-04-15',3,2,'GREAL','2732 Baker Blvd.',11006,'Great Lakes Food Market','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('87110','Albuquerque','1997-07-08',13.75,'NM','1997-06-10','1997-06-16',4,3,'RATTC','2817 Milton Dr.','Rattlesnake Canyon Grocery',10564,'USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('69004','Lyon','1997-03-27',25.09,'1997-02-27','1997-02-28',4,2,'VICTE','2, rue du Commerce','Victuailles en stock',10459,'France');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Resende','08737-363','1997-07-29',13.41,'SP','1997-07-01','1997-07-10',7,1,'Rua do Mercado, 12','WELLI','Wellington Importadora',10585,'Brazil');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('28001','Madrid','1996-09-12',12.69,'1996-08-15','1996-08-21',4,1,'ROMEY','Gran Vía, 1','Romero y tomillo',10282,'Spain');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('Colchester','CO7 6JX','1998-03-31',29.61,'Essex','1998-03-03','1998-03-09',4,2,'AROUT','Brook Farm Stratford St. Mary','Around the Horn',10920,'UK');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('Colchester','CO7 6JX','1998-01-21',4.52,'Essex','1997-12-24','1998-01-08',3,3,'AROUT','Brook Farm Stratford St. Mary','Around the Horn',10793,'UK');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('87110','Albuquerque','1998-06-03',8.53,'NM','1998-05-06',1,2,'RATTC','2817 Milton Dr.','Rattlesnake Canyon Grocery',11077,'USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('5020','Salzburg','1997-04-25',5.29,'1997-03-28','1997-04-09',6,2,'PICCO','Geislweg 14','Piccolo und mehr',10489,'Austria');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('3012','Bern','1997-12-17',31.43,'1997-11-19','1997-11-21',1,3,'Hauptstr. 31','CHOPS','Chop-suey Chinese',10746,'Switzerland');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('1204','Genève','1997-05-28',78.85,'1997-05-14','1997-05-19',1,1,'RICSU','Starenweg 5','Richter Supermarkt',10537,'Switzerland');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('3012','Bern','1996-08-08',22.98,'1996-07-11','1996-07-23',5,2,'Hauptstr. 31','CHOPS','Chop-suey Chinese',10254,'Switzerland');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01307','Cunewalde','1997-06-10',171.24,'1997-05-27','1997-05-30',5,1,'QUICK','Taucherstraße 10',10549,'QUICK-Stop','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01307','Cunewalde','1998-04-07',31.89,'1998-03-10','1998-03-16',3,2,'QUICK','Taucherstraße 10',10938,'QUICK-Stop','Germany');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Charleroi','B-6000','1998-05-18',0.17,'1998-04-20','1998-04-24',2,2,'Boulevard Tirou, 255','SUPRD','Suprêmes délices',11035,'Belgium');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('44087','Münster','1997-06-23',1.43,'1997-05-26','1997-06-02',3,2,'TOMSP','Luisenstr. 48',10548,'Toms Spezialitäten','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('80805','München','1996-11-21',108.26,'1996-10-24','1996-10-29',4,3,'FRANK','Berliner Platz 43',10337,'Frankenversand','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('70563','Stuttgart','1997-09-11',41.38,'1997-08-14','1997-08-19',8,1,'WANDK','Adenauerallee 900',10632,'Die Wandernde Kuh','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('99508','Anchorage','1998-06-01',40.32,'AK','1998-04-20','1998-04-27',8,1,'OLDWO','2743 Bering St.',11034,'Old World Delicatessen','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('83720','Boise','1997-11-19',24.49,'ID','1997-10-22','1997-10-27',5,3,'SAVEA','187 Suffolk Ln.',10714,'Save-a-lot Markets','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('13008','Marseille','1997-12-24',16.71,'1997-11-26','1997-11-28',4,2,'BONAP','12, rue des Bouchers',10755,'Bon app''','France');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('97403','Eugene','1997-08-01',4.42,'OR','1997-07-04','1997-07-14',8,2,'GREAL','2732 Baker Blvd.',10589,'Great Lakes Food Market','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('99508','Anchorage','1997-11-13',135.63,'AK','1997-10-16','1997-10-21',8,3,'OLDWO','2743 Bering St.',10706,'Old World Delicatessen','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('8200','Århus','1997-12-15',69.19,'1997-11-17','1997-11-24',6,1,'VAFFE','Smagsloget 45','Vaffeljernet',10744,'Denmark');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('90110','Oulu','1998-05-13',29.17,'1998-04-15','1998-04-24',6,3,'Torikatu 38','WARTH','Wartian Herkku',11025,'Finland');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01307','Cunewalde','1997-03-05',189.09,'1997-02-19','1997-03-12',4,3,'QUICK','Taucherstraße 10',10451,'QUICK-Stop','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('8010','Graz','1998-05-13',117.61,'1998-04-01','1998-04-07',2,3,'Kirchgasse 6','ERNSH','Ernst Handel',10990,'Austria');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Cowes','PO31 7PJ','1997-10-16',0.9,'Isle of Wight','1997-09-18','1997-09-30',4,2,'Garden House Crowther Way','ISLAT','Island Trading',10674,'UK');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01307','Cunewalde','1997-06-02',41.9,'1997-05-05','1997-05-07',7,1,'QUICK','Taucherstraße 10',10527,'QUICK-Stop','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('52066','Aachen','1998-05-18',7.98,'1998-05-04','1998-05-06',1,2,'DRACD','Walserweg 21','Drachenblut Delikatessen',11067,'Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01307','Cunewalde','1997-05-07',204.47,'1997-04-23','1997-05-23',2,1,'QUICK','Taucherstraße 10',10515,'QUICK-Stop','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('13008','Marseille','1998-06-03',38.28,'1998-05-06',4,2,'BONAP','12, rue des Bouchers','Bon app''',11076,'France');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('82520','Lander','1997-02-14',4.34,'WY','1997-01-31','1997-02-07',3,2,'SPLIR','P.O. Box 555','Split Rail Beer & Ale',10432,'USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('83720','Boise','1996-11-05',214.27,'ID','1996-10-08','1996-10-10',9,1,'SAVEA','187 Suffolk Ln.',10324,'Save-a-lot Markets','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01-012','Warszawa','1998-03-04',12.04,'1998-02-04','1998-02-13',5,3,'WOLZA','ul. Filtrowa 68',10870,'Wolski Zajazd','Poland');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('50739','Köln','1997-02-04',91.48,'1997-01-07','1997-01-30',2,2,'OTTIK','Mehrheimerstr. 369',10407,'Ottilies Käseladen','Germany');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Luleå','S-958 22','1997-05-29',244.79,'1997-05-01','1997-05-07',1,2,'Berguvsvägen  8','BERGS','Berglunds snabbköp',10524,'Sweden');
# INSERT INTO orders (ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Cork','1997-10-27',220.31,'Co. Cork','1997-10-13','1997-10-15',6,3,'8 Johnstown Road','HUNGO','Hungry Owl All-Night Grocers',10701,'Ireland');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('Sao Paulo','05487-020','1998-01-16',110.87,'SP','1997-12-19','1997-12-23',8,1,'QUEEN','Alameda dos Canàrios, 891','Queen Cozinha',10786,'Brazil');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('13008','Marseille','1996-11-26',166.31,'1996-10-29','1996-11-08',1,3,'BONAP','12, rue des Bouchers',10340,'Bon app''','France');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('83720','Boise','1997-03-20',140.26,'ID','1997-02-20','1997-02-26',8,1,'SAVEA','187 Suffolk Ln.',10452,'Save-a-lot Markets','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('8010','Graz','1998-04-20',74.6,'1998-03-23','1998-04-01',1,3,'Kirchgasse 6','ERNSH','Ernst Handel',10968,'Austria');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('Colchester','CO7 6JX','1997-01-13',34.24,'Essex','1996-12-16','1996-12-18',8,3,'AROUT','Brook Farm Stratford St. Mary','Around the Horn',10383,'UK');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Tsawassen','T2F 8M4','1998-05-22',24.12,'BC','1998-04-24','1998-04-30',7,3,'23 Tsawassen Blvd.','BOTTM','Bottom-Dollar Markets',11048,'Canada');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('67000','Strasbourg','1996-12-20',131.7,'1996-11-22','1996-12-02',4,3,'BLONP','24, place Kléber',10360,'Blondel père et fils','France');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('69004','Lyon','1998-01-28',22.11,'1997-12-31','1998-01-05',3,2,'VICTE','2, rue du Commerce','Victuailles en stock',10806,'France');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Sao Paulo','05442-030','1996-12-04',3.1,'SP','1996-11-06','1996-11-08',4,3,'Rua Orós, 92','FAMIA','Familia Arquibaldo',10347,'Brazil');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('13008','Marseille','1998-03-09',60.42,'1998-02-09','1998-02-12',7,3,'BONAP','12, rue des Bouchers',10876,'Bon app''','France');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('67000','Strasbourg','1997-07-10',88.4,'1997-06-12','1997-06-18',9,1,'BLONP','24, place Kléber',10566,'Blondel père et fils','France');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('London','OX15 4NB','1998-03-04',143.28,'1998-02-04','1998-02-09',5,1,'90 Wadhurst Rd.','SEVES','Seven Seas Imports',10869,'UK');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('31000','Toulouse','1997-02-21',7.93,'1997-01-24','1997-02-14',6,2,'LAMAI','1 rue Alsace-Lorraine',10425,'La maison d''Asie','France');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Bruxelles','B-1180','1997-06-04',66.69,'1997-05-07','1997-05-09',5,2,'Rue Joseph-Bens 532','MAISD','Maison Dewey',10529,'Belgium');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('London','EC2 5NT','1997-08-26',29.98,'1997-07-15','1997-07-21',6,3,'Fauntleroy Circus','BSBEV','B''s Beverages',10599,'UK');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('1204','Genève','1998-06-03',6.19,'1998-05-06',8,2,'RICSU','Starenweg 5','Richter Supermarkt',11075,'Switzerland');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('London','EC2 5NT','1997-04-21',6.88,'1997-03-24','1997-04-01',3,3,'Fauntleroy Circus','BSBEV','B''s Beverages',10484,'UK');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('24100','Bergamo','1996-09-04',26.93,'1996-08-07','1996-08-09',1,1,'MAGAA','Via Ludovico il Moro 22','Magazzini Alimentari Riuniti',10275,'Italy');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('8010','Graz','1997-08-07',96.78,'1997-07-10','1997-07-14',2,1,'Kirchgasse 6','ERNSH','Ernst Handel',10595,'Austria');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('01307','Cunewalde','1997-10-03',364.15,'1997-09-05','1997-09-08',4,1,'QUICK','Taucherstraße 10',10658,'QUICK-Stop','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('87110','Albuquerque','1998-05-04',55.12,'NM','1998-04-06','1998-04-14',2,3,'RATTC','2817 Milton Dr.','Rattlesnake Canyon Grocery',11000,'USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('69004','Lyon','1997-04-01',4.81,'1997-03-18','1997-03-26',2,3,'VICTE','2, rue du Commerce','Victuailles en stock',10478,'France');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('59801','Butte','1997-09-04',94.8,'MT','1997-08-07','1997-08-19',4,2,'THECR','55 Grizzly Peak Rd.',10624,'The Cracker Box','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('12209','Berlin','1997-09-22',29.46,'1997-08-25','1997-09-02',6,1,'ALFKI','Obere Str. 57',10643,'Alfreds Futterkiste','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('8010','Graz','1997-12-31',145.45,'1997-12-03','1997-12-08',6,3,'Kirchgasse 6','ERNSH','Ernst Handel',10764,'Austria');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('42100','Reggio Emilia','1997-03-12',13.95,'1997-02-12','1997-02-14',8,1,'REGGC','Strada Provinciale 124',10443,'Reggiani Caseifici','Italy');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('San Cristóbal','5022','1997-04-23',30.53,'Táchira','1997-03-26','1997-04-02',1,2,'HILAA','Carrera 22 con Ave. Carlos Soublette #8-35','HILARION-Abastos',10486,'Venezuela');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('Sao Paulo','05487-020','1998-03-26',33.05,'SP','1998-02-26','1998-03-04',4,1,'QUEEN','Alameda dos Canàrios, 891','Queen Cozinha',10913,'Brazil');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('1675','Lisboa','1997-07-09',72.95,'1997-05-28','1997-06-06',4,3,'FURIB','Jardim das rosas n. 32','Furia Bacalhau e Frutos do Mar',10551,'Portugal');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('90110','Oulu','1997-09-16',1.15,'1997-08-19','1997-08-26',4,1,'Torikatu 38','WARTH','Wartian Herkku',10636,'Finland');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('50739','Köln','1997-06-27',120.97,'1997-05-30','1997-06-05',4,3,'OTTIK','Mehrheimerstr. 369',10554,'Ottilies Käseladen','Germany');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('London','OX15 4NB','1997-06-20',178.43,'1997-05-23','1997-06-02',3,2,'90 Wadhurst Rd.','SEVES','Seven Seas Imports',10547,'UK');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('83720','Boise','1998-04-27',211.22,'ID','1998-03-30','1998-04-03',1,3,'SAVEA','187 Suffolk Ln.',10984,'Save-a-lot Markets','USA');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('50739','Köln','1997-05-14',4.99,'1997-04-16','1997-05-13',1,2,'OTTIK','Mehrheimerstr. 369',10508,'Ottilies Käseladen','Germany');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,order_id,ship_name,ship_country) VALUES ('13008','Marseille','1997-11-06',63.2,'1997-10-23','1997-10-29',3,1,'BONAP','12, rue des Bouchers',10715,'Bon app''','France');
# INSERT INTO orders (ship_postal_code,ship_city,required_date,freight,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('28023','Madrid','1998-01-26',97.09,'1997-12-29','1997-12-31',4,2,'BOLID','C/ Araquil, 67','Bólido Comidas preparadas',10801,'Spain');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Montréal','H1J 1C3','1997-07-15',188.99,'Québec','1997-06-17','1997-06-19',3,3,'43 rue St. Laurent','MEREP','Mère Paillarde',10570,'Canada');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,customer_id,ship_address,ship_name,order_id,ship_country) VALUES ('San Cristóbal','5022','1998-04-15',105.36,'Táchira','1998-03-18','1998-03-27',8,3,'HILAA','Carrera 22 con Ave. Carlos Soublette #8-35','HILARION-Abastos',10957,'Venezuela');
# INSERT INTO orders (ship_city,ship_postal_code,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Rio de Janeiro','02389-890','1997-03-14',68.66,'RJ','1997-02-14','1997-03-07',4,2,'Av. Copacabana, 267','RICAR','Ricardo Adocicados',10447,'Brazil');
# INSERT INTO orders (ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Cork','1997-01-02',124.12,'Co. Cork','1996-12-05','1996-12-11',4,3,'8 Johnstown Road','HUNGO','Hungry Owl All-Night Grocers',10373,'Ireland');
# INSERT INTO orders (ship_city,required_date,freight,ship_region,order_date,shipped_date,employee_id,ship_via,ship_address,customer_id,ship_name,order_id,ship_country) VALUES ('Cork','1997-11-18',89.93,'Co. Cork','1997-10-21','1997-10-31',3,1,'8 Johnstown Road','HUNGO','Hungry Owl All-Night Grocers',10712,'Ireland');
# ...
# INSERT INTO products (reorder_level,category_id,units_in_stock,units_on_order,product_id,quantity_per_unit,discontinued,unit_price,product_name,supplier_id) VALUES (20,2,4,100,66,'24 - 8 oz jars',0,17.0,'Louisiana Hot Spiced Okra',2);
# INSERT INTO products (reorder_level,category_id,units_in_stock,units_on_order,product_id,quantity_per_unit,discontinued,unit_price,product_name,supplier_id) VALUES (0,3,15,0,26,'100 - 250 g bags',0,31.23,'Gumbär Gummibärchen',11);
# INSERT INTO products (reorder_level,category_id,units_in_stock,units_on_order,product_id,quantity_per_unit,discontinued,unit_price,product_name,supplier_id) VALUES (25,4,9,40,32,'24 - 200 g pkgs.',0,32.0,'Mascarpone Fabioli',14);
# INSERT INTO products (reorder_level,category_id,units_on_order,units_in_stock,product_id,quantity_per_unit,discontinued,unit_price,product_name,supplier_id) VALUES (20,1,0,57,76,'500 ml',0,18.0,'Lakkalikööri',23);
# INSERT INTO products (reorder_level,category_id,units_in_stock,units_on_order,product_id,quantity_per_unit,discontinued,unit_price,product_name,supplier_id) VALUES (30,3,76,0,25,'20 - 450 g glasses',0,14.0,'NuNuCa Nuß-Nougat-Creme',11);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,supplier_id,contact_title,homepage) VALUES ('Germany','Martin Bein','Bogenallee 51','Frankfurt','(069) 992755','Plutzer Lebensmittelgroßmärkte AG','60439',12,'International Marketing Mgr.','Plutzer (on the World Wide Web)#http://www.microsoft.com/accessdev/sampleapps/plutzer.htm#');
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,region,contact_title,supplier_id) VALUES ('Canada','Jean-Guy Lauzon','2960 Rue St. Laurent','Montréal','(514) 555-9022','Ma Maison','H1J 1C3','Québec','Marketing Manager',25);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,fax,postal_code,contact_title,supplier_id) VALUES ('Denmark','Niels Petersen','Lyngbysild Fiskebakken 10','Lyngby','43844108','Lyngbysild','43844115','2800','Sales Manager',21);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,contact_title,supplier_id) VALUES ('Germany','Petra Winkler','Tiergartenstraße 5','Berlin','(010) 9984510','Heli Süßwaren GmbH & Co. KG','10785','Sales Manager',11);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,contact_title,supplier_id) VALUES ('Japan','Yoshi Nagase','9-8 Sekimai Musashino-shi','Tokyo','(03) 3555-5011','Tokyo Traders','100','Marketing Manager',4);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,region,contact_title,supplier_id) VALUES ('Spain','Antonio del Valle Saavedra','Calle del Rosal 4','Oviedo','(98) 598 76 54','Cooperativa de Quesos ''Las Cabras''','33007','Asturias','Export Administrator',5);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,fax,postal_code,region,supplier_id,contact_title) VALUES ('USA','Regina Murphy','707 Oxford Rd.','Ann Arbor','(313) 555-5735','Grandma Kelly''s Homestead','(313) 555-3349','48104','MI',3,'Sales Representative');
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,postal_code,contact_title,supplier_id) VALUES ('Finland','Anne Heikkonen','Valtakatu 12','(953) 10956','Lappeenranta','Karkki Oy','53120','Product Manager',23);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,contact_title,supplier_id) VALUES ('UK','Charlotte Cooper','49 Gilbert St.','London','(171) 555-2222','Exotic Liquids','EC1 4SD','Purchasing Manager',1);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,contact_title,supplier_id) VALUES ('UK','Peter Wilson','29 King''s Way','Manchester','(161) 555-4448','Specialty Biscuits, Ltd.','M14 GSD','Sales Representative',8);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,contact_title,supplier_id) VALUES ('Singapore','Chandra Leka','471 Serangoon Loop, Suite #402','Singapore','555-8787','Leka Trading','0512','Owner',20);
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,fax,postal_code,supplier_id,contact_title) VALUES ('Germany','Sven Petersen','Frahmredder 112a','(04721) 8713','Cuxhaven','Nord-Ost-Fisch Handelsgesellschaft mbH','(04721) 8714','27478',13,'Coordinator Foreign Markets');
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,fax,postal_code,contact_title,supplier_id) VALUES ('Sweden','Lars Peterson','Kaloadagatan 13','Göteborg','031-987 65 43','PB Knäckebröd AB','031-987 65 91','S-345 67','Sales Agent',9);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,contact_title,supplier_id) VALUES ('France','Marie Delamare','22, rue H. Voiron','Montceau','85.57.00.07','Escargots Nouveaux','71300','Sales Manager',27);
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,postal_code,contact_title,supplier_id,homepage) VALUES ('Japan','Mayumi Ohno','92 Setsuko Chuo-ku','(06) 431-7877','Osaka','Mayumi''s','545','Marketing Representative',6,'Mayumi''s (on the World Wide Web)#http://www.microsoft.com/accessdev/sampleapps/mayumi.htm#');
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,contact_title,supplier_id) VALUES ('Brazil','Carlos Diaz','Av. das Americanas 12.890','Sao Paulo','(11) 555 4640','Refrescos Americanas LTDA','5442','Marketing Manager',10);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,fax,postal_code,contact_title,supplier_id) VALUES ('Netherlands','Dirk Luchte','Verkoop Rijnweg 22','Zaandam','(12345) 1212','Zaanse Snoepfabriek','(12345) 1210','9999 ZZ','Accounting Manager',22);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,region,supplier_id,contact_title) VALUES ('USA','Cheryl Saylor','3400 - 8th Avenue Suite 210','Bend','(503) 555-9931','Bigfoot Breweries','97101','OR',16,'Regional Account Rep.');
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,postal_code,contact_title,supplier_id) VALUES ('Norway','Beate Vileid','Hatlevegen 5','(0)2-953010','Sandvika','Norske Meierier','1320','Marketing Manager',15);
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,postal_code,region,supplier_id,contact_title,homepage) VALUES ('USA','Shelley Burke','P.O. Box 78934','(100) 555-4822','New Orleans','New Orleans Cajun Delights','70117','LA',2,'Order Administrator','#CAJUN.HTM#');
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,postal_code,fax,region,contact_title,supplier_id) VALUES ('Canada','Chantal Goulet','148 rue Chasseur','(514) 555-2955','Ste-Hyacinthe','Forêts d''érables','J2S 7S8','(514) 555-2921','Québec','Accounting Manager',29);
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,fax,postal_code,region,contact_title,supplier_id) VALUES ('Australia','Ian Devling','74 Rose St. Moonie Ponds','(03) 444-2343','Melbourne','Pavlova, Ltd.','(03) 444-6588','3058','Victoria','Marketing Manager',7);
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,fax,region,supplier_id,contact_title,homepage) VALUES ('Australia','Wendy Mackenzie','170 Prince Edward Parade Hunter''s Hill','Sydney','(02) 555-5914','G''day, Mate','2042','(02) 555-4873','NSW',24,'Sales Representative','G''day Mate (on the World Wide Web)#http://www.microsoft.com/accessdev/sampleapps/gdaymate.htm#');
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,fax,postal_code,contact_title,supplier_id,homepage) VALUES ('Italy','Elio Rossi','Viale Dante, 75','Ravenna','(0544) 60323','Formaggi Fortini s.r.l.','(0544) 60603','48100','Sales Representative',14,'#FORMAGGI.HTM#');
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,fax,postal_code,region,supplier_id,contact_title) VALUES ('USA','Robb Merchant','Order Processing Dept. 2100 Paul Revere Blvd.','(617) 555-3267','Boston','New England Seafood Cannery','(617) 555-3389','02134','MA',19,'Wholesale Account Agent');
# INSERT INTO suppliers (country,contact_name,address,city,phone,company_name,postal_code,fax,contact_title,supplier_id) VALUES ('France','Eliane Noz','Bat. B 3, rue des Alpes','Annecy','38.76.98.06','Gai pâturage','74000','38.76.98.58','Sales Representative',28);
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,fax,postal_code,contact_title,supplier_id) VALUES ('Italy','Giovanni Giudici','Via dei Gelsomini, 153','(089) 6547665','Salerno','Pasta Buttini s.r.l.','(089) 6547667','84100','Order Administrator',26);
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,postal_code,contact_title,supplier_id) VALUES ('Sweden','Michael Björn','Brovallavägen 231','08-123 45 67','Stockholm','Svensk Sjöföda AB','S-123 45','Sales Representative',17);
# INSERT INTO suppliers (country,contact_name,address,phone,city,company_name,fax,postal_code,contact_title,supplier_id) VALUES ('France','Guylène Nodier','203, Rue des Francs-Bourgeois','(1) 03.83.00.68','Paris','Aux joyeux ecclésiastiques','(1) 03.83.00.62','75004','Sales Manager',18);
# INSERT INTO categories (description,category_name,category_id,picture) VALUES ('Desserts, candies, and sweet breads','Confections',3,'<memory at 0x1265a0dc0>');
# INSERT INTO categories (description,category_name,category_id,picture) VALUES ('Dried fruit and bean curd','Produce',7,'<memory at 0x1265a3100>');
# INSERT INTO categories (description,category_name,category_id,picture) VALUES ('Sweet and savory sauces, relishes, spreads, and seasonings','Condiments',2,'<memory at 0x1265a0d00>');
# INSERT INTO categories (description,category_name,category_id,picture) VALUES ('Soft drinks, coffees, teas, beers, and ales','Beverages',1,'<memory at 0x1265a0c40>');
# INSERT INTO categories (description,category_name,category_id,picture) VALUES ('Seaweed and fish','Seafood',8,'<memory at 0x1265a31c0>');
# INSERT INTO categories (description,category_name,category_id,picture) VALUES ('Prepared meats','Meat/Poultry',6,'<memory at 0x1265a3040>');
# INSERT INTO categories (description,category_name,category_id,picture) VALUES ('Breads, crackers, pasta, and cereal','Grains/Cereals',5,'<memory at 0x1265a0f40>');
# INSERT INTO categories (description,category_name,category_id,picture) VALUES ('Cheeses','Dairy Products',4,'<memory at 0x1265a0e80>');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','WA',48,'Washington');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','TX',44,'Texas');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','SC',41,'South Carolina');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','DE',8,'Delaware');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('north','MI',23,'Michigan');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','WY',51,'Wyoming');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','NC',34,'North Carolina');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','LA',19,'Louisiana');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','WV',49,'West Virginia');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','NJ',31,'New Jersey');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','WI',50,'Wisconsin');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','ID',13,'Idaho');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','MS',25,'Mississippi');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','OH',36,'Ohio');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','PA',39,'Pennsylvania');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','UT',45,'Utah');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','IO',16,'Iowa');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','CO',6,'Colorado');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','KY',18,'Kentucky');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','NH',30,'New Hampshire');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('north','MA',22,'Massachusetts');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','NM',32,'New Mexico');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','VT',46,'Vermont');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','OK',37,'Oklahoma');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','CA',5,'California');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('north','AK',2,'Alaska');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','GA',11,'Georgia');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','CT',7,'Connecticut');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','AL',1,'Alabama');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','KS',17,'Kansas');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','ND',35,'North Dakota');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','FL',10,'Florida');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','MT',27,'Montana');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','AR',4,'Arkansas');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('south','MO',26,'Missouri');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','NY',33,'New York');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('north','ME',20,'Maine');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','OR',38,'Oregon');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','RI',40,'Rhode Island');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('north','MN',24,'Minnesota');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','NE',28,'Nebraska');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','AZ',3,'Arizona');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','MD',21,'Maryland');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','IN',15,'Indiana');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','VA',47,'Virginia');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','TN',43,'Tennessee');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','SD',42,'South Dakota');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','NV',29,'Nevada');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('midwest','IL',14,'Illinois');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('west','HI',12,'Hawaii');
# INSERT INTO us_states (state_region,state_abbr,state_id,state_name) VALUES ('east','DC',9,'District of Columbia');

# %%
database = "northwind_map"

# %%
for nc in ncs:
    print(nc.label, len(nc.nodes))
# Out:
# territories 53
# employees 9
# region 4
# orders 830
# shippers 6
# customers 91
# products 77
# suppliers 29
# categories 8
# us_states 51

# %%
with open("/Users/a.palagashvili/coursework/psql/queries/tmp.sql", "w") as out:

    print(f"DROP DATABASE {database};", file=out)
    print(f"CREATE DATABASE {database};", file=out)
    print(f"\c {database};", file=out)
    print("\n\n", file=out)
    
    for nc in ncs:
        deletion = generate_deletion(nc)
        migration = generate_migration(nc)
        print(deletion, file=out)
        print(migration, file=out)
        print("\n\n", file=out)

    for nc in ncs:
        print(*generate_inserts_for_nodeClass(nc), sep='\n', file=out)
        print("\n\n", file=out)

    for nc in ncs:
        print(generate_pk_constraint(nc), file=out)

    print("\n\n", file=out)
    for ec in ecs:
        src_many, tgt_many, has_attr = is_m2m(ec.edges)
        if has_attr or (src_many and tgt_many):
            print(generate_deletion(ec), file=out)
            print(generate_migration(ec), file=out)
            print(*generate_inserts_for_edgeClass(ec), sep="\n", file=out)
            print("\n\n", file=out)

    for ec in ecs:
        src_many, tgt_many, has_attr = is_m2m(ec.edges)
        if not has_attr and (not src_many or not tgt_many):
            if src_many:
                source, target = ec.source, ec.target
                q = f"ALTER TABLE ONLY {source} ADD CONSTRAINT fk_{source}_{target} FOREIGN KEY ({ec.label}) REFERENCES {target};"
                print(q, file=out)
            if tgt_many:
                source, target = ec.source, ec.target
                q = f"ALTER TABLE ONLY {target} ADD CONSTRAINT fk_{target}_{source} FOREIGN KEY ({ec.label}) REFERENCES {source};"
                print(q, file=out)

        else:
            source, target = ec.source, ec.target
            for nc in ncs:
                if nc.label == source:
                    source_nc = nc
            for attr in ec.attr:
                if attr.name in source_nc.pk:
                    source_fk = attr.name

            for nc in ncs:
                if nc.label == target:
                    target_nc = nc
            for attr in ec.attr:
                if attr.name in target_nc.pk:
                    target_fk = attr.name

            q = f"ALTER TABLE ONLY {ec.label} ADD CONSTRAINT pk_{ec.label} PRIMARY KEY ({source_fk}, {target_fk});"
            print(q, file=out)

            q = f"ALTER TABLE ONLY {ec.label} ADD CONSTRAINT fk_{ec.label}_{source} FOREIGN KEY ({source_fk}) REFERENCES {source};"
            print(q, file=out)
            q = f"ALTER TABLE ONLY {ec.label} ADD CONSTRAINT fk_{ec.label}_{target} FOREIGN KEY ({target_fk}) REFERENCES {target};"
            print(q, file=out)

# %%
def generate_fk_contraint_o2m(ec):
    source =

# %%
for ec in ecs:
    src_many, tgt_many, has_attr = is_m2m(ec.edges)
    if not has_attr and (not src_many or not tgt_many):
        if src_many:
            source, target = ec.source, ec.target
            q = f"ALTER TABLE ONLY {source} ADD CONSTRAINT fk_{source}_{target} FOREIGN KEY ({ec.label}) REFERENCES {target};"
            print(q)
        if tgt_many:
            source, target = ec.source, ec.target
            q = f"ALTER TABLE ONLY {target} ADD CONSTRAINT fk_{target}_{source} FOREIGN KEY ({ec.label}) REFERENCES {source};"
            print(q)
            
    else:
        source, target = ec.source, ec.target
        for nc in ncs:
            if nc.label == source:
                source_nc = nc
        for attr in ec.attr:
            if attr.name in source_nc.pk:
                source_fk = attr.name
        
        for nc in ncs:
            if nc.label == target:
                target_nc = nc
        for attr in ec.attr:
            if attr.name in target_nc.pk:
                target_fk = attr.name
        
        q = f"ALTER TABLE ONLY {ec.label} ADD CONSTRAINT pk_{ec.label} PRIMARY KEY ({source_fk}, {target_fk});"
        print(q)
        
        q = f"ALTER TABLE ONLY {ec.label} ADD CONSTRAINT fk_{ec.label}_{source} FOREIGN KEY ({source_fk}) REFERENCES {source};"
        print(q)
        q = f"ALTER TABLE ONLY {ec.label} ADD CONSTRAINT fk_{ec.label}_{target} FOREIGN KEY ({target_fk}) REFERENCES {target};"
        print(q)
# Out:
# ALTER TABLE ONLY employee_territories ADD CONSTRAINT pk_employee_territories PRIMARY KEY (territory_id, employee_id);
# ALTER TABLE ONLY employee_territories ADD CONSTRAINT fk_employee_territories_territories FOREIGN KEY (territory_id) REFERENCES territories;
# ALTER TABLE ONLY employee_territories ADD CONSTRAINT fk_employee_territories_employees FOREIGN KEY (employee_id) REFERENCES employees;
# ALTER TABLE ONLY territories ADD CONSTRAINT fk_territories_region FOREIGN KEY (region_id) REFERENCES region;
# ALTER TABLE ONLY orders ADD CONSTRAINT fk_orders_shippers FOREIGN KEY (ship_via) REFERENCES shippers;
# ALTER TABLE ONLY orders ADD CONSTRAINT fk_orders_employees FOREIGN KEY (employee_id) REFERENCES employees;
# ALTER TABLE ONLY orders ADD CONSTRAINT fk_orders_customers FOREIGN KEY (customer_id) REFERENCES customers;
# ALTER TABLE ONLY employees ADD CONSTRAINT fk_employees_employees FOREIGN KEY (reports_to) REFERENCES employees;
# ALTER TABLE ONLY order_details ADD CONSTRAINT pk_order_details PRIMARY KEY (product_id, order_id);
# ALTER TABLE ONLY order_details ADD CONSTRAINT fk_order_details_products FOREIGN KEY (product_id) REFERENCES products;
# ALTER TABLE ONLY order_details ADD CONSTRAINT fk_order_details_orders FOREIGN KEY (order_id) REFERENCES orders;
# ALTER TABLE ONLY products ADD CONSTRAINT fk_products_suppliers FOREIGN KEY (supplier_id) REFERENCES suppliers;
# ALTER TABLE ONLY products ADD CONSTRAINT fk_products_categories FOREIGN KEY (category_id) REFERENCES categories;

# %%
source_nc.pk
# Out:
# {'territory_id'}

# %%
for attr in ec.attr:
    if attr.name in source_nc.pk:
        source_fk = attr.name

# %%
source_fk
# Out:
# 'territory_id'

# %%
target_nc.label
# Out:
# 'employees'

# %%
for nc in ncs:
    if nc.label == "employees":
        break

# %%
nc.label
# Out:
# 'employees'

# %%
ec.source, ec.target
# Out:
# ('territories', 'employees')

# %%
schema = GraphSchema(ncs, [])

# %%
# generate migrations for tables

# %%
tuples['orders'][0].attr
# Out:
# ('ship_postal_code',
#  'ship_city',
#  'required_date',
#  'freight',
#  'order_date',
#  'shipped_date',
#  'employee_id',
#  'ship_via',
#  'customer_id',
#  'ship_address',
#  'ship_name',
#  'order_id',
#  'ship_country')

# %%
type(tuples['orders'][0].vals[3]) == float
# Out:
# True

# %%
len(t)
# Out:
# 108

# %%
t[0]

# %%
t[0] == t[1]
# Out:
# False

# %%
t = []
for k in tuples['employees']:
    if k.vals[-1] == "Andrew":
        if k not in t:
            t.append(k)
            print(k.vals)
# Out:
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ...
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']
# ['(206) 555-9482', 'USA', '3457', 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and Italian and reads German.  He joined the company as a sales representative, was promoted to sales manager in January 1992 and to vice president of sales in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', '908 W. Capital Way', 'Dr.', 'Tacoma', '1952-02-19', '<memory at 0x1456b6940>', 'Fuller', '1992-08-14', 'Vice President, Sales', 'http://accweb/emmployees/fuller.bmp', 2, 'WA', '98401', 'Andrew']

# %%
len(tuples['employees'])
# Out:
# 895

# %%
n = triplets[0][0]

# %%
n
# Out:
# <Node id=1 labels=frozenset({'territories'}) properties={'region_id': 1, 'territory_description': 'Westboro', 'territory_id': '01581'}>

# %%
e = triplets[0][1]

# %%
edgeMapper(e)

# %%
e.keys()
# Out:
# dict_keys(['territory_id', 'employee_id'])

# %%
len(triplets)
# Out:
# 16481

# %%
node = nodes[0]['n']

# %%
list(node.labels)[0]
# Out:
# 'suppliers'

# %%
node.keys()
# Out:
# ['n']

# %%
list(result)
# Out:
# []

# %%
result

# %%
result = [item for item in result]

# %%
result
# Out:
# []
